# %%
import csv

Data = []
with open("newCSV.csv",'w',newline='') as newfile:
    wr = csv.writer(newfile)


    with open("TargetCSV.txt",'r') as file:
        for line in file.readlines():
            if (not ('%' in line)):
                X = line.split()
                Data.append(X)
                print(len(line.split()))
                wr.writerow(X)
# Out:
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 0
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 0
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 0
# 53
# 52

# %%
 X = """ 12,345 	  107 
  4,001 	  33 
  73,843 	  158 
  9,957 	  0   
  928,801 	  5,789 
  37,743 	  156 
  45,439 	  4,523 
  4,872 	  53 
  6,847 	  162 
  388,086 	  14,103 
  88,950 	  2,641 
  19,006 	  191 
  4,903 	  66 
  128,770 	  348 
  19,676 	  57 
  7,353 	  13 
  10,480 	  57 
  8,449 	  14 
  19,177 	  387 
  3,127 	  71 
  69,882 	  1,624 
  73,304 	  12,284 
  43,008 	  240 
  22,639 	  227 
  5,586 	  37 
  16,093 	  59 
  2,259 	  39 
  5,456 	  0
  34,766 	  372 
  5,858 	  267 
  139,640 	  5,231 
  15,488 	  0   
  355,575 	  5,002 
  53,518 	  609 
  965 	  22 
  31,025 	  173 
  14,847 	  25 
  31,707 	  206 
  56,370 	  1,657 
  8,131 	  304 
  18,407 	  726 
1199	 0
  24,281 	  63 
  382,460 	  1,901 
  14,912 	  285 
  2,673 	  12 
  77,043 	  637 
  66,901 	  446 
  1,699 	  2 
  15,082 	  46 
  841 	  15 """

# %%
u  = 1
k,l = ([],[])
for i in X.split():
    if u>0:
        k.append(i.replace(",",""))
    else:
        l.append(i.replace(",",""))
    u = -1*u
    print (i)
# Out:
# 12,345
# 107
# 4,001
# 33
# 73,843
# 158
# 9,957
# 0
# 928,801
# 5,789
# 37,743
# 156
# 45,439
# 4,523
# 4,872
# 53
# 6,847
# 162
# 388,086
# 14,103
# 88,950
# 2,641
# 19,006
# 191
# 4,903
# 66
# 128,770
# 348
# 19,676
# 57
# 7,353
# 13
# 10,480
# 57
# 8,449
# 14
# 19,177
# 387
# 3,127
# 71
# 69,882
# 1,624
# 73,304
# 12,284
# 43,008
# 240
# 22,639
# 227
# 5,586
# 37
# 16,093
# 59
# 2,259
# 39
# 5,456
# 0
# 34,766
# 372
# 5,858
# 267
# 139,640
# 5,231
# 15,488
# 0
# 355,575
# 5,002
# 53,518
# 609
# 965
# 22
# 31,025
# 173
# 14,847
# 25
# 31,707
# 206
# 56,370
# 1,657
# 8,131
# 304
# 18,407
# 726
# 1199
# 0
# 24,281
# 63
# 382,460
# 1,901
# 14,912
# 285
# 2,673
# 12
# 77,043
# 637
# 66,901
# 446
# 1,699
# 2
# 15,082
# 46
# 841
# 15

# %%
print(k)
# Out:
# ['12345', '4001', '73843', '9957', '928801', '37743', '45439', '4872', '6847', '388086', '88950', '19006', '4903', '128770', '19676', '7353', '10480', '8449', '19177', '3127', '69882', '73304', '43008', '22639', '5586', '16093', '2259', '5456', '34766', '5858', '139640', '15488', '355575', '53518', '965', '31025', '14847', '31707', '56370', '8131', '18407', '1199', '24281', '382460', '14912', '2673', '77043', '66901', '1699', '15082', '841']
